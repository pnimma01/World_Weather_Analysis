# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#len(cities)

# %%
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather['weather'][0]['description']
        #print(f"here is the description -----{city_weather_description}")
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Weather Description": city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | mosina
# Processing Record 3 of Set 1 | misasi
# Processing Record 4 of Set 1 | caravelas
# Processing Record 5 of Set 1 | havelock
# Processing Record 6 of Set 1 | kondagaon
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | benghazi
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | paita
# Processing Record 14 of Set 1 | montijo
# Processing Record 15 of Set 1 | xuddur
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | sorland
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | balkhash
# Processing Record 21 of Set 1 | grimari
# City not found. Skipping...
# Processing Record 22 of Set 1 | chicama
# Processing Record 23 of Set 1 | trabzon
# Processing Record 24 of Set 1 | korla
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | bereda
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | quarai
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 1 | semey
# Processing Record 34 of Set 1 | chateaudun
# Processing Record 35 of Set 1 | yarmouth
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | save
# Processing Record 40 of Set 1 | dingle
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | san pedro
# Processing Record 43 of Set 1 | adre
# Processing Record 44 of Set 1 | hagere hiywet
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | puquio
# Processing Record 47 of Set 1 | muisne
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | abu dhabi
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | general roca
# Processing Record 2 of Set 2 | atar
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | stykkisholmur
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | margate
# Processing Record 11 of Set 2 | nelidovo
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | radyvyliv
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | nador
# Processing Record 16 of Set 2 | jaisalmer
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | san luis
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | ekibastuz
# Processing Record 22 of Set 2 | husavik
# Processing Record 23 of Set 2 | ostrovnoy
# Processing Record 24 of Set 2 | pocone
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | camana
# Processing Record 27 of Set 2 | bilma
# Processing Record 28 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 2 | bolzano
# Processing Record 30 of Set 2 | copiapo
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | longyearbyen
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | santomera
# Processing Record 35 of Set 2 | lomintsevskiy
# Processing Record 36 of Set 2 | olafsvik
# Processing Record 37 of Set 2 | maceio
# Processing Record 38 of Set 2 | lauder
# Processing Record 39 of Set 2 | tazovskiy
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | buta
# Processing Record 44 of Set 2 | los llanos de aridane
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | ormara
# Processing Record 47 of Set 2 | siavonga
# Processing Record 48 of Set 2 | hobyo
# Processing Record 49 of Set 2 | gidole
# Processing Record 50 of Set 2 | vila velha
# Processing Record 1 of Set 3 | amboasary
# Processing Record 2 of Set 3 | les mureaux
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | mattru
# Processing Record 5 of Set 3 | tigre
# Processing Record 6 of Set 3 | santa vitoria do palmar
# Processing Record 7 of Set 3 | bella vista
# Processing Record 8 of Set 3 | abha
# Processing Record 9 of Set 3 | necochea
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | wexford
# Processing Record 12 of Set 3 | rocha
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | yugo-kamskiy
# Processing Record 15 of Set 3 | ust-kulom
# Processing Record 16 of Set 3 | richards bay
# Processing Record 17 of Set 3 | dera bugti
# Processing Record 18 of Set 3 | burica
# City not found. Skipping...
# Processing Record 19 of Set 3 | porto novo
# Processing Record 20 of Set 3 | tessalit
# Processing Record 21 of Set 3 | ogaminana
# Processing Record 22 of Set 3 | coruripe
# Processing Record 23 of Set 3 | boende
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | zlobin
# Processing Record 26 of Set 3 | pokhara
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | taltal
# Processing Record 29 of Set 3 | faya
# Processing Record 30 of Set 3 | aswan
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | agbor
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | jiwani
# Processing Record 35 of Set 3 | envira
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | bafia
# Processing Record 38 of Set 3 | brae
# Processing Record 39 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 3 | kalmunai
# Processing Record 41 of Set 3 | zhezkazgan
# Processing Record 42 of Set 3 | upington
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | lilongwe
# Processing Record 45 of Set 3 | buraydah
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | dawlatabad
# Processing Record 48 of Set 3 | pedra branca
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | maridi
# Processing Record 2 of Set 4 | mananjary
# Processing Record 3 of Set 4 | alashtar
# City not found. Skipping...
# Processing Record 4 of Set 4 | nanortalik
# Processing Record 5 of Set 4 | esil
# Processing Record 6 of Set 4 | senanga
# Processing Record 7 of Set 4 | male
# Processing Record 8 of Set 4 | punta arenas
# Processing Record 9 of Set 4 | palpa
# Processing Record 10 of Set 4 | inhambane
# Processing Record 11 of Set 4 | parsabad
# Processing Record 12 of Set 4 | mineros
# Processing Record 13 of Set 4 | eyl
# Processing Record 14 of Set 4 | quixada
# Processing Record 15 of Set 4 | chupa
# Processing Record 16 of Set 4 | wilmington
# Processing Record 17 of Set 4 | opuwo
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | grindavik
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | sao jose da coroa grande
# Processing Record 22 of Set 4 | kidodi
# Processing Record 23 of Set 4 | san cristobal
# Processing Record 24 of Set 4 | plettenberg bay
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | puerto cabezas
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | batak
# Processing Record 29 of Set 4 | puerto quijarro
# Processing Record 30 of Set 4 | taoudenni
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | nadym
# Processing Record 33 of Set 4 | mattawa
# Processing Record 34 of Set 4 | saint-joseph
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | araouane
# Processing Record 38 of Set 4 | abu samrah
# Processing Record 39 of Set 4 | san carlos de bariloche
# Processing Record 40 of Set 4 | dosso
# Processing Record 41 of Set 4 | eenhana
# Processing Record 42 of Set 4 | maragogi
# Processing Record 43 of Set 4 | quchan
# Processing Record 44 of Set 4 | andenes
# Processing Record 45 of Set 4 | svetlogorsk
# Processing Record 46 of Set 4 | tarko-sale
# Processing Record 47 of Set 4 | trofors
# Processing Record 48 of Set 4 | pangnirtung
# Processing Record 49 of Set 4 | tiznit
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | boa esperanca do sul
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | horta
# Processing Record 4 of Set 5 | iquique
# Processing Record 5 of Set 5 | ponta delgada
# Processing Record 6 of Set 5 | illapel
# Processing Record 7 of Set 5 | kokkola
# Processing Record 8 of Set 5 | gornopravdinsk
# Processing Record 9 of Set 5 | urucara
# Processing Record 10 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 5 | norrtalje
# Processing Record 12 of Set 5 | ushtobe
# Processing Record 13 of Set 5 | padang
# Processing Record 14 of Set 5 | beloha
# Processing Record 15 of Set 5 | adet
# Processing Record 16 of Set 5 | ambatolampy
# Processing Record 17 of Set 5 | bambous virieux
# Processing Record 18 of Set 5 | ilo
# Processing Record 19 of Set 5 | pallasovka
# Processing Record 20 of Set 5 | iskateley
# Processing Record 21 of Set 5 | goderich
# Processing Record 22 of Set 5 | camacha
# Processing Record 23 of Set 5 | virginia beach
# Processing Record 24 of Set 5 | cap malheureux
# Processing Record 25 of Set 5 | teguldet
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 5 | gat
# Processing Record 29 of Set 5 | senneterre
# Processing Record 30 of Set 5 | lima
# Processing Record 31 of Set 5 | ortona
# Processing Record 32 of Set 5 | manta
# Processing Record 33 of Set 5 | sao joao da barra
# Processing Record 34 of Set 5 | turukhansk
# Processing Record 35 of Set 5 | akureyri
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | numan
# Processing Record 38 of Set 5 | marrakesh
# Processing Record 39 of Set 5 | damara
# Processing Record 40 of Set 5 | miraflores
# Processing Record 41 of Set 5 | adrar
# Processing Record 42 of Set 5 | areosa
# Processing Record 43 of Set 5 | kuytun
# Processing Record 44 of Set 5 | changji
# Processing Record 45 of Set 5 | coihaique
# Processing Record 46 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 5 | carauari
# Processing Record 48 of Set 5 | atasu
# Processing Record 49 of Set 5 | maniitsoq
# Processing Record 50 of Set 5 | sakakah
# Processing Record 1 of Set 6 | oksfjord
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | lasa
# Processing Record 4 of Set 6 | praia
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | kiruna
# Processing Record 7 of Set 6 | coldwater
# Processing Record 8 of Set 6 | encruzilhada do sul
# Processing Record 9 of Set 6 | petrolina
# Processing Record 10 of Set 6 | bubaque
# Processing Record 11 of Set 6 | lodja
# Processing Record 12 of Set 6 | tshikapa
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | portsmouth
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | ngorongoro
# Processing Record 17 of Set 6 | wanlaweyn
# Processing Record 18 of Set 6 | bronnoysund
# Processing Record 19 of Set 6 | kroderen
# City not found. Skipping...
# Processing Record 20 of Set 6 | vryheid
# Processing Record 21 of Set 6 | santa barbara
# Processing Record 22 of Set 6 | limon
# Processing Record 23 of Set 6 | kisesa
# Processing Record 24 of Set 6 | salalah
# Processing Record 25 of Set 6 | belmonte
# Processing Record 26 of Set 6 | maltahohe
# Processing Record 27 of Set 6 | barcelos
# Processing Record 28 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 6 | nsoko
# Processing Record 30 of Set 6 | kalisz
# Processing Record 31 of Set 6 | piacabucu
# Processing Record 32 of Set 6 | oranjemund
# Processing Record 33 of Set 6 | sihora
# Processing Record 34 of Set 6 | saint-augustin
# Processing Record 35 of Set 6 | yabrud
# Processing Record 36 of Set 6 | magugu
# Processing Record 37 of Set 6 | vila franca do campo
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | canton
# Processing Record 40 of Set 6 | parana
# Processing Record 41 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 6 | syracuse
# Processing Record 43 of Set 6 | nefteyugansk
# Processing Record 44 of Set 6 | bathsheba
# Processing Record 45 of Set 6 | usinsk
# Processing Record 46 of Set 6 | toktogul
# Processing Record 47 of Set 6 | vestmannaeyjar
# Processing Record 48 of Set 6 | maputo
# Processing Record 49 of Set 6 | plymouth
# Processing Record 50 of Set 6 | jacqueville
# Processing Record 1 of Set 7 | jacareacanga
# Processing Record 2 of Set 7 | huarmey
# Processing Record 3 of Set 7 | icatu
# Processing Record 4 of Set 7 | borovoy
# Processing Record 5 of Set 7 | portage
# Processing Record 6 of Set 7 | saint anthony
# Processing Record 7 of Set 7 | igarka
# Processing Record 8 of Set 7 | betafo
# Processing Record 9 of Set 7 | pozoblanco
# Processing Record 10 of Set 7 | chilca
# Processing Record 11 of Set 7 | carutapera
# Processing Record 12 of Set 7 | nuevitas
# Processing Record 13 of Set 7 | rawson
# Processing Record 14 of Set 7 | westport
# Processing Record 15 of Set 7 | naliya
# Processing Record 16 of Set 7 | cayenne
# Processing Record 17 of Set 7 | nieuw amsterdam
# Processing Record 18 of Set 7 | payyannur
# Processing Record 19 of Set 7 | serebryansk
# Processing Record 20 of Set 7 | nuuk
# Processing Record 21 of Set 7 | bardiyah
# Processing Record 22 of Set 7 | shelburne
# Processing Record 23 of Set 7 | joinville
# Processing Record 24 of Set 7 | balykshi
# Processing Record 25 of Set 7 | marsabit
# Processing Record 26 of Set 7 | hambantota
# Processing Record 27 of Set 7 | loralai
# Processing Record 28 of Set 7 | astorga
# Processing Record 29 of Set 7 | krasnoznamensk
# Processing Record 30 of Set 7 | san isidro
# Processing Record 31 of Set 7 | bafq
# Processing Record 32 of Set 7 | matay
# Processing Record 33 of Set 7 | berea
# Processing Record 34 of Set 7 | tobermory
# Processing Record 35 of Set 7 | nantucket
# Processing Record 36 of Set 7 | estancia
# Processing Record 37 of Set 7 | muros
# Processing Record 38 of Set 7 | saint-leu
# Processing Record 39 of Set 7 | mitu
# Processing Record 40 of Set 7 | san joaquin
# Processing Record 41 of Set 7 | channel-port aux basques
# Processing Record 42 of Set 7 | lerwick
# Processing Record 43 of Set 7 | maracacume
# Processing Record 44 of Set 7 | les cayes
# Processing Record 45 of Set 7 | puerto baquerizo moreno
# Processing Record 46 of Set 7 | yurla
# Processing Record 47 of Set 7 | shushtar
# Processing Record 48 of Set 7 | nizwa
# Processing Record 49 of Set 7 | oranjestad
# Processing Record 50 of Set 7 | navalmoral de la mata
# Processing Record 1 of Set 8 | santa maria
# Processing Record 2 of Set 8 | ilhabela
# Processing Record 3 of Set 8 | nyuksenitsa
# Processing Record 4 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 8 | tosno
# Processing Record 6 of Set 8 | el vigia
# Processing Record 7 of Set 8 | willowmore
# Processing Record 8 of Set 8 | saint-pierre
# Processing Record 9 of Set 8 | asyut
# Processing Record 10 of Set 8 | mogadishu
# Processing Record 11 of Set 8 | san giuliano terme
# Processing Record 12 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | wattegama
# Processing Record 15 of Set 8 | youkounkoun
# Processing Record 16 of Set 8 | narsaq
# Processing Record 17 of Set 8 | ndele
# Processing Record 18 of Set 8 | alghero
# Processing Record 19 of Set 8 | donskoye
# Processing Record 20 of Set 8 | malartic
# Processing Record 21 of Set 8 | itaituba
# Processing Record 22 of Set 8 | salinopolis
# Processing Record 23 of Set 8 | zharkent
# Processing Record 24 of Set 8 | springdale
# Processing Record 25 of Set 8 | alta floresta
# Processing Record 26 of Set 8 | hofn
# Processing Record 27 of Set 8 | riyadh
# Processing Record 28 of Set 8 | nalut
# Processing Record 29 of Set 8 | karaton
# Processing Record 30 of Set 8 | naryan-mar
# Processing Record 31 of Set 8 | ilulissat
# Processing Record 32 of Set 8 | andros town
# Processing Record 33 of Set 8 | istisu
# Processing Record 34 of Set 8 | sao lourenco da serra
# Processing Record 35 of Set 8 | liverpool
# Processing Record 36 of Set 8 | chama
# Processing Record 37 of Set 8 | kapuskasing
# Processing Record 38 of Set 8 | marinette
# Processing Record 39 of Set 8 | sirsa
# Processing Record 40 of Set 8 | palora
# Processing Record 41 of Set 8 | acarau
# Processing Record 42 of Set 8 | cacule
# Processing Record 43 of Set 8 | gumdag
# Processing Record 44 of Set 8 | sassandra
# Processing Record 45 of Set 8 | memari
# Processing Record 46 of Set 8 | sesheke
# Processing Record 47 of Set 8 | nayagarh
# Processing Record 48 of Set 8 | klaksvik
# Processing Record 49 of Set 8 | koster
# Processing Record 50 of Set 8 | leh
# Processing Record 1 of Set 9 | hargeysa
# Processing Record 2 of Set 9 | manjeshwar
# Processing Record 3 of Set 9 | wamba
# Processing Record 4 of Set 9 | marovoay
# Processing Record 5 of Set 9 | ambilobe
# Processing Record 6 of Set 9 | aktau
# Processing Record 7 of Set 9 | brigantine
# Processing Record 8 of Set 9 | port-cartier
# Processing Record 9 of Set 9 | ardea
# Processing Record 10 of Set 9 | lovozero
# Processing Record 11 of Set 9 | menongue
# Processing Record 12 of Set 9 | xai-xai
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | falkoping
# City not found. Skipping...
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | terrak
# Processing Record 17 of Set 9 | kulhudhuffushi
# Processing Record 18 of Set 9 | honavar
# Processing Record 19 of Set 9 | notodden
# Processing Record 20 of Set 9 | mumford
# Processing Record 21 of Set 9 | zabid
# Processing Record 22 of Set 9 | remerschen
# Processing Record 23 of Set 9 | erbaa
# Processing Record 24 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 9 | aden
# Processing Record 26 of Set 9 | rio tercero
# Processing Record 27 of Set 9 | baherden
# Processing Record 28 of Set 9 | minas
# Processing Record 29 of Set 9 | upata
# Processing Record 30 of Set 9 | ouadda
# Processing Record 31 of Set 9 | paamiut
# Processing Record 32 of Set 9 | yabelo
# Processing Record 33 of Set 9 | vardo
# Processing Record 34 of Set 9 | balkanabat
# Processing Record 35 of Set 9 | oum hadjer
# Processing Record 36 of Set 9 | olinda
# Processing Record 37 of Set 9 | rudbar
# Processing Record 38 of Set 9 | kharan
# Processing Record 39 of Set 9 | bara
# Processing Record 40 of Set 9 | pucallpa
# Processing Record 41 of Set 9 | farsund
# Processing Record 42 of Set 9 | belyy yar
# Processing Record 43 of Set 9 | podyuga
# Processing Record 44 of Set 9 | bud
# Processing Record 45 of Set 9 | pocoes
# Processing Record 46 of Set 9 | puerto leguizamo
# Processing Record 47 of Set 9 | tingo maria
# Processing Record 48 of Set 9 | yuksekova
# Processing Record 49 of Set 9 | amapa
# Processing Record 50 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 10 | sarny
# Processing Record 2 of Set 10 | yershov
# Processing Record 3 of Set 10 | rio gallegos
# Processing Record 4 of Set 10 | uddevalla
# Processing Record 5 of Set 10 | weligama
# Processing Record 6 of Set 10 | belogorsk
# Processing Record 7 of Set 10 | imeni zhelyabova
# Processing Record 8 of Set 10 | kontagora
# Processing Record 9 of Set 10 | ustrzyki dolne
# Processing Record 10 of Set 10 | aksarka
# Processing Record 11 of Set 10 | praia da vitoria
# Processing Record 12 of Set 10 | maarianhamina
# Processing Record 13 of Set 10 | cape coast
# Processing Record 14 of Set 10 | otuzco
# Processing Record 15 of Set 10 | ayorou
# Processing Record 16 of Set 10 | jalingo
# Processing Record 17 of Set 10 | bana
# Processing Record 18 of Set 10 | surt
# Processing Record 19 of Set 10 | promysla
# City not found. Skipping...
# Processing Record 20 of Set 10 | thunder bay
# Processing Record 21 of Set 10 | shubarkuduk
# Processing Record 22 of Set 10 | aguimes
# Processing Record 23 of Set 10 | reinosa
# Processing Record 24 of Set 10 | thinadhoo
# Processing Record 25 of Set 10 | berkak
# Processing Record 26 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | trincomalee
# Processing Record 29 of Set 10 | bulungu
# Processing Record 30 of Set 10 | luanda
# Processing Record 31 of Set 10 | baheri
# Processing Record 32 of Set 10 | lafia
# Processing Record 33 of Set 10 | urdoma
# Processing Record 34 of Set 10 | pinhao
# Processing Record 35 of Set 10 | komatipoort
# Processing Record 36 of Set 10 | tvoroyri
# Processing Record 37 of Set 10 | marsaxlokk
# Processing Record 38 of Set 10 | marinha grande
# Processing Record 39 of Set 10 | urengoy
# Processing Record 40 of Set 10 | colonia
# Processing Record 41 of Set 10 | lieksa
# Processing Record 42 of Set 10 | roald
# Processing Record 43 of Set 10 | jonkoping
# Processing Record 44 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 10 | bracebridge
# Processing Record 46 of Set 10 | soyo
# Processing Record 47 of Set 10 | gloucester
# Processing Record 48 of Set 10 | kindu
# Processing Record 49 of Set 10 | asenovgrad
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | gelibolu
# Processing Record 2 of Set 11 | dudinka
# Processing Record 3 of Set 11 | bandar-e lengeh
# Processing Record 4 of Set 11 | quelimane
# Processing Record 5 of Set 11 | wyoming
# Processing Record 6 of Set 11 | lichinga
# Processing Record 7 of Set 11 | tekirdag
# Processing Record 8 of Set 11 | shieli
# Processing Record 9 of Set 11 | medvedok
# Processing Record 10 of Set 11 | turayf
# Processing Record 11 of Set 11 | benguela
# Processing Record 12 of Set 11 | narasannapeta
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | kizema
# Processing Record 15 of Set 11 | ascension
# Processing Record 16 of Set 11 | yacuiba
# Processing Record 17 of Set 11 | kogon
# Processing Record 18 of Set 11 | port blair
# Processing Record 19 of Set 11 | san juan
# Processing Record 20 of Set 11 | namwala
# Processing Record 21 of Set 11 | sept-iles
# Processing Record 22 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 23 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 11 | cabedelo
# Processing Record 25 of Set 11 | telimele
# Processing Record 26 of Set 11 | bahia blanca
# Processing Record 27 of Set 11 | salgueiro
# Processing Record 28 of Set 11 | krosno
# Processing Record 29 of Set 11 | monrovia
# Processing Record 30 of Set 11 | reading
# Processing Record 31 of Set 11 | catalina
# Processing Record 32 of Set 11 | oyem
# Processing Record 33 of Set 11 | shakhunya
# Processing Record 34 of Set 11 | los andes
# Processing Record 35 of Set 11 | ornskoldsvik
# Processing Record 36 of Set 11 | moncton
# Processing Record 37 of Set 11 | neuquen
# Processing Record 38 of Set 11 | vagur
# Processing Record 39 of Set 11 | businga
# Processing Record 40 of Set 11 | puerto ayora
# Processing Record 41 of Set 11 | kourou
# Processing Record 42 of Set 11 | awjilah
# Processing Record 43 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | aras
# Processing Record 45 of Set 11 | turiacu
# Processing Record 46 of Set 11 | berberati
# Processing Record 47 of Set 11 | banes
# Processing Record 48 of Set 11 | humaita
# Processing Record 49 of Set 11 | lake city
# Processing Record 50 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 12 | kautokeino
# Processing Record 2 of Set 12 | bloemfontein
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | colomi
# Processing Record 5 of Set 12 | kitob
# Processing Record 6 of Set 12 | tromso
# Processing Record 7 of Set 12 | nara
# Processing Record 8 of Set 12 | senador jose porfirio
# Processing Record 9 of Set 12 | bonavista
# Processing Record 10 of Set 12 | luleburgaz
# Processing Record 11 of Set 12 | dalvik
# Processing Record 12 of Set 12 | kingseat
# Processing Record 13 of Set 12 | ardino
# Processing Record 14 of Set 12 | nizhnyaya omka
# Processing Record 15 of Set 12 | tabou
# Processing Record 16 of Set 12 | nzerekore
# Processing Record 17 of Set 12 | diofior
# Processing Record 18 of Set 12 | yumaguzino
# Processing Record 19 of Set 12 | kousseri
# Processing Record 20 of Set 12 | methoni
# Processing Record 21 of Set 12 | ejigbo
# Processing Record 22 of Set 12 | riachao
# Processing Record 23 of Set 12 | bhatkal
# Processing Record 24 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 12 | palaia fokaia
# Processing Record 26 of Set 12 | gijon
# Processing Record 27 of Set 12 | umm lajj
# Processing Record 28 of Set 12 | lages
# Processing Record 29 of Set 12 | marsa matruh
# Processing Record 30 of Set 12 | trelew
# Processing Record 31 of Set 12 | mecca
# Processing Record 32 of Set 12 | meulaboh
# Processing Record 33 of Set 12 | selty
# Processing Record 34 of Set 12 | anori
# Processing Record 35 of Set 12 | abidjan
# Processing Record 36 of Set 12 | kirn
# Processing Record 37 of Set 12 | pondicherry
# Processing Record 38 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 12 | viedma
# Processing Record 40 of Set 12 | pryozerne
# Processing Record 41 of Set 12 | vieux-habitants
# Processing Record 42 of Set 12 | mesyagutovo
# Processing Record 43 of Set 12 | stornoway
# Processing Record 44 of Set 12 | bereslavka
# Processing Record 45 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 12 | senekal
# Processing Record 47 of Set 12 | bam
# Processing Record 48 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 12 | beyneu
# Processing Record 50 of Set 12 | lincoln
# Processing Record 1 of Set 13 | villamontes
# Processing Record 2 of Set 13 | mairipora
# Processing Record 3 of Set 13 | embonas
# Processing Record 4 of Set 13 | vallenar
# Processing Record 5 of Set 13 | lipari
# Processing Record 6 of Set 13 | kembe
# Processing Record 7 of Set 13 | tshane
# Processing Record 8 of Set 13 | conceicao do araguaia
# Processing Record 9 of Set 13 | waddan
# Processing Record 10 of Set 13 | bandarbeyla
# Processing Record 11 of Set 13 | berlevag
# Processing Record 12 of Set 13 | dingli
# Processing Record 13 of Set 13 | chiriqui grande
# Processing Record 14 of Set 13 | havoysund
# Processing Record 15 of Set 13 | kapiri mposhi
# Processing Record 16 of Set 13 | nokaneng
# Processing Record 17 of Set 13 | thaba-tseka
# Processing Record 18 of Set 13 | ler
# Processing Record 19 of Set 13 | asfi
# Processing Record 20 of Set 13 | alice town
# Processing Record 21 of Set 13 | highland springs
# Processing Record 22 of Set 13 | swellendam
# Processing Record 23 of Set 13 | mathathane
# Processing Record 24 of Set 13 | kangavar
# Processing Record 25 of Set 13 | springbok
# Processing Record 26 of Set 13 | yarensk
# Processing Record 27 of Set 13 | mmathubudukwane
# Processing Record 28 of Set 13 | beira
# Processing Record 29 of Set 13 | arlit
# Processing Record 30 of Set 13 | viseu
# Processing Record 31 of Set 13 | sambava
# Processing Record 32 of Set 13 | sur
# Processing Record 33 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 13 | kyshtovka
# Processing Record 35 of Set 13 | bayji
# Processing Record 36 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 13 | saint austell
# Processing Record 39 of Set 13 | mosquera
# Processing Record 40 of Set 13 | jiguani
# Processing Record 41 of Set 13 | veraval
# Processing Record 42 of Set 13 | kangaatsiaq
# Processing Record 43 of Set 13 | yenagoa
# Processing Record 44 of Set 13 | santarem
# Processing Record 45 of Set 13 | qandala
# Processing Record 46 of Set 13 | south river
# Processing Record 47 of Set 13 | sayyan
# Processing Record 48 of Set 13 | esna
# Processing Record 49 of Set 13 | kattivakkam
# Processing Record 50 of Set 13 | gamba
# Processing Record 1 of Set 14 | havre-saint-pierre
# Processing Record 2 of Set 14 | dubti
# Processing Record 3 of Set 14 | pisco
# Processing Record 4 of Set 14 | laguna de perlas
# Processing Record 5 of Set 14 | shar
# Processing Record 6 of Set 14 | volodarka
# Processing Record 7 of Set 14 | rumonge
# Processing Record 8 of Set 14 | saint-louis
# Processing Record 9 of Set 14 | agustin codazzi
# Processing Record 10 of Set 14 | bloomingdale
# Processing Record 11 of Set 14 | remetea mare
# Processing Record 12 of Set 14 | dobroye
# Processing Record 13 of Set 14 | vilhena
# Processing Record 14 of Set 14 | betera
# Processing Record 15 of Set 14 | atlantic city
# Processing Record 16 of Set 14 | nuevo imperial
# Processing Record 17 of Set 14 | zarand
# Processing Record 18 of Set 14 | ndjole
# Processing Record 19 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 14 | grand-lahou
# Processing Record 21 of Set 14 | rodrigues alves
# Processing Record 22 of Set 14 | skjervoy
# Processing Record 23 of Set 14 | milos
# Processing Record 24 of Set 14 | wilkes-barre
# Processing Record 25 of Set 14 | emborion
# Processing Record 26 of Set 14 | khoy
# Processing Record 27 of Set 14 | rute
# Processing Record 28 of Set 14 | jalu
# Processing Record 29 of Set 14 | beruwala
# Processing Record 30 of Set 14 | truro
# Processing Record 31 of Set 14 | conde
# Processing Record 32 of Set 14 | muzhi
# Processing Record 33 of Set 14 | colares
# Processing Record 34 of Set 14 | kharitonovo
# Processing Record 35 of Set 14 | chulym
# Processing Record 36 of Set 14 | harper
# Processing Record 37 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 14 | gilbues
# Processing Record 39 of Set 14 | luena
# Processing Record 40 of Set 14 | chipinge
# Processing Record 41 of Set 14 | paarl
# Processing Record 42 of Set 14 | junin
# Processing Record 43 of Set 14 | isakly
# Processing Record 44 of Set 14 | rio pardo
# Processing Record 45 of Set 14 | lewisporte
# Processing Record 46 of Set 14 | chokwe
# Processing Record 47 of Set 14 | mayahi
# Processing Record 48 of Set 14 | gargzdai
# Processing Record 49 of Set 14 | biu
# Processing Record 50 of Set 14 | amantea
# Processing Record 1 of Set 15 | moussoro
# Processing Record 2 of Set 15 | yanam
# Processing Record 3 of Set 15 | saint stephen
# Processing Record 4 of Set 15 | bafata
# Processing Record 5 of Set 15 | mwinilunga
# Processing Record 6 of Set 15 | tukrah
# Processing Record 7 of Set 15 | suksun
# Processing Record 8 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 9 of Set 15 | anloga
# Processing Record 10 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 11 of Set 15 | tripoli
# Processing Record 12 of Set 15 | parakou
# Processing Record 13 of Set 15 | manoel urbano
# Processing Record 14 of Set 15 | pordim
# Processing Record 15 of Set 15 | saint-francois
# Processing Record 16 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 15 | trairi
# Processing Record 18 of Set 15 | wajir
# Processing Record 19 of Set 15 | leshukonskoye
# Processing Record 20 of Set 15 | igrim
# Processing Record 21 of Set 15 | hun
# Processing Record 22 of Set 15 | springfield
# Processing Record 23 of Set 15 | mitsamiouli
# Processing Record 24 of Set 15 | ciudad dario
# Processing Record 25 of Set 15 | calama
# Processing Record 26 of Set 15 | basarabeasca
# Processing Record 27 of Set 15 | agadir
# Processing Record 28 of Set 15 | marienburg
# Processing Record 29 of Set 15 | porto velho
# Processing Record 30 of Set 15 | alamor
# Processing Record 31 of Set 15 | natal
# Processing Record 32 of Set 15 | tocopilla
# Processing Record 33 of Set 15 | imbituba
# Processing Record 34 of Set 15 | mabaruma
# Processing Record 35 of Set 15 | puerto narino
# Processing Record 36 of Set 15 | sile
# Processing Record 37 of Set 15 | jumla
# Processing Record 38 of Set 15 | uitenhage
# Processing Record 39 of Set 15 | comodoro rivadavia
# Processing Record 40 of Set 15 | dakoro
# Processing Record 41 of Set 15 | mwandiga
# Processing Record 42 of Set 15 | san martin
# Processing Record 43 of Set 15 | presidencia roque saenz pena
# Processing Record 44 of Set 15 | kensington
# Processing Record 45 of Set 15 | khash
# Processing Record 46 of Set 15 | vegachi
# Processing Record 47 of Set 15 | iberia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#city_data
#add the data to new dataframe
weather_conditions_df=pd.DataFrame(city_data)
weather_conditions_df=weather_conditions_df[['City','Country','Lat', 'Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Weather Description']]
weather_conditions_df.head()
# Out:
#         City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Cidreira      BR -30.1811 -50.2056     73.83        81          67
# 1     Mosina      PL  52.2454  16.8471     31.33        86           0
# 2     Misasi      TZ  -3.0000  33.0833     62.96        96         100
# 3  Caravelas      BR -17.7125 -39.2481     76.50        83         100
# 4   Havelock      US  34.8791 -76.9013     58.95        72         100
#
#    Wind Speed Current Weather Description
# 0       18.45               broken clouds
# 1        4.61                   clear sky
# 2        4.43             overcast clouds
# 3        3.60             overcast clouds
# 4        5.75             overcast clouds

# %%
#save the results to a csv file
file_to_save = "WeatherPy_Database.csv"
from os.path import exists
file_exists = exists(file_to_save)
if not file_exists:
    weather_conditions_df.to_csv(file_to_save)
else:
    weather_conditions_df_f = pd.read_csv(file_to_save)
    weather_conditions_df_f.head()
