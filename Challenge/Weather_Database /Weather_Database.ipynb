# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
#lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#len(cities)

# %%
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather['weather'][0]['description']
        #print(f"here is the description -----{city_weather_description}")
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Weather Description": city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | karlstad
# Processing Record 2 of Set 1 | alyangula
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | kama
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | san quintin
# Processing Record 12 of Set 1 | atbasar
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | thompson
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 1 | vokhtoga
# Processing Record 20 of Set 1 | sao filipe
# ...

# %%
#city_data
#add the data to new dataframe
weather_conditions_df=pd.DataFrame(city_data)
weather_conditions_df=weather_conditions_df[['City','Country','Lat', 'Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Weather Description']]
weather_conditions_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Karlstad      SE  59.3793   13.5036     25.36       100         100
# 1       Alyangula      AU -13.8483  136.4192     84.07        84         100
# 2  Port Elizabeth      ZA -33.9180   25.5701     73.69        73          20
# 3        Souillac      MU -20.5167   57.5167     80.98        89          75
# 4            Kama      RU  56.3051   54.0936     30.38        98         100
#
#    Wind Speed Current Weather Description
# 0        5.75             overcast clouds
# 1        6.91             overcast clouds
# 2       25.32                  few clouds
# 3       25.32               moderate rain
# 4        4.00                  light snow

# %%
#save the results to a csv file
file_to_save = "WeatherPy_Database.csv"
from os.path import exists
file_exists = exists(file_to_save)
if not file_exists:
    weather_conditions_df.to_csv(file_to_save)
else:
    weather_conditions_df_f = pd.read_csv(file_to_save)
    weather_conditions_df_f.head()
